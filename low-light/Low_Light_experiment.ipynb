# %%
import sys
import os

project_root = os.path.abspath(".")  # notebook location
sys.path.insert(0, project_root)

# %%
print(sys.path)
# Out:
# ['/home/aanbarasu/teams/project-team-50/night-light', '/home/aanbarasu/.conda/envs/opencv_env/lib/python311.zip', '/home/aanbarasu/.conda/envs/opencv_env/lib/python3.11', '/home/aanbarasu/.conda/envs/opencv_env/lib/python3.11/lib-dynload', '', '/home/aanbarasu/.conda/envs/opencv_env/lib/python3.11/site-packages']

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from Python_LIME.LIME import lime
import pylime

# %%
def show(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
loc = '../custom_dataset/raw_images/ucsd_night'+'2'+'_frame_0000'+'9'+'.jpg'

# %%
img = cv2.imread(loc, cv2.IMREAD_COLOR)

# %%
dir(cv2.intensity_transform)
# Out:
# ['BIMEF',
#  'BIMEF2',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_native',
#  'autoscaling',
#  'contrastStretching',
#  'gammaCorrection',
#  'logTransform']

# %%
bimef_img = cv2.intensity_transform.BIMEF(img)

# %%
output = np.zeros_like(img)
cv2.intensity_transform.gammaCorrection(img, output, 0.1)

# %%
lime_img = lime(img)
# Out:
# Weight generation strategy: 3
# Strategy parameters: sigma = 2, kernel size = 15
# Solved: <class 'numpy.ndarray'>

# %%
l = pylime.lime(img)      
lime_cpp_img = l.lime_enhance(img)

# %%
show(img)

# %%
show(bimef_img)

# %%
show(output)

# %%
show(lime_img)

# %%
show(lime_cpp_img)
