# %%
import torch

# Load the checkpoint
ckpt = torch.load("/home/aanbarasu/.cache/sparse_rcnn_r50_fpn_3x_det_bdd100k.pth")

# Check the type
print(type(ckpt))  # likely <class 'collections.OrderedDict'>

# # Wrap it if needed
# if isinstance(ckpt, dict) and "model" not in ckpt:
#     ckpt = {"model": ckpt}

# # Save it back
# torch.save(ckpt, "/home/aanbarasu/.cache/sparse_rcnn_r50_fpn_3x_det_bdd100k.pth")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import torch
#       3 # Load the checkpoint
# ----> 4 ckpt = torch.load("/home/aanbarasu/.cache/sparse_rcnn_r50_fpn_3x_det_bdd100k.pth")
#       6 # Check the type
#       7 print(type(ckpt))  # likely <class 'collections.OrderedDict'>
#
# File /opt/conda/lib/python3.11/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
# ...
